# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
matplotlib.__version__
# Out:
# '3.7.0'

# %%
# %matplotlib inline

# %%
path = r'C:\Users\brian\OneDrive\Desktop\Section 6\02 Data\Prepared Data'

# %%
df = pd.read_csv(os.path.join(path, 'Happiness Reports.csv'))

# %%
df.shape
# Out:
# (782, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Rank', 'Score', 'GDP_Capita', 'Family',
#        'Life_Expectancy', 'Freedom', 'Gov_Corruption', 'Generosity',
#        'Dystopia', 'Region'],
#       dtype='object')

# %%
# Rename columns

df.rename(columns = {'Score' : 'Happiness Score'}, inplace = True)

# %%
df.dtypes
# Out:
# Country             object
# Year                 int64
# Rank                 int64
# Happiness Score    float64
# GDP_Capita         float64
# Family             float64
# Life_Expectancy    float64
# Freedom            float64
# Gov_Corruption     float64
# Generosity         float64
# Dystopia           float64
# Region              object
# dtype: object

# %%
df.head()
# Out:
#        Country  Year  Rank  Happiness Score  GDP_Capita   Family  \
# 0  Switzerland  2015     1            7.587     1.39651  1.34951
# 1      Iceland  2015     2            7.561     1.30232  1.40223
# 2      Denmark  2015     3            7.527     1.32548  1.36058
# 3       Norway  2015     4            7.522     1.45900  1.33095
# 4       Canada  2015     5            7.427     1.32629  1.32261
#
#    Life_Expectancy  Freedom  Gov_Corruption  Generosity  Dystopia  \
# 0          0.94143  0.66557         0.41978     0.29678   2.51738
# 1          0.94784  0.62877         0.14145     0.43630   2.70201
# 2          0.87464  0.64938         0.48357     0.34139   2.49204
# 3          0.88521  0.66973         0.36503     0.34699   2.46531
# 4          0.90563  0.63297         0.32957     0.45811   2.45176
#
#            Region
# 0  Western Europe
# 1  Western Europe
# 2  Western Europe
# 3  Western Europe
# 4   North America

# %%
df.isnull().sum()
# Out:
# Country              0
# Year                 0
# Rank                 0
# Happiness Score      0
# GDP_Capita           0
# Family               0
# Life_Expectancy      0
# Freedom              0
# Gov_Corruption       1
# Generosity           0
# Dystopia           312
# Region             467
# dtype: int64

# %%
df_dups = df[df.duplicated()]

# %%
df_dups.shape #No duplicates
# Out:
# (0, 12)

# %%
#3  Create a correlation matrix heatmap (colored).

# %%
df.corr()
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_7252\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Year      Rank  Happiness Score  GDP_Capita    Family  \
# Year             1.000000 -0.007768         0.007065    0.019768  0.367431
# Rank            -0.007768  1.000000        -0.992066   -0.794791 -0.644842
# Happiness Score  0.007065 -0.992066         1.000000    0.789284  0.648799
# GDP_Capita       0.019768 -0.794791         0.789284    1.000000  0.585966
# Family           0.367431 -0.644842         0.648799    0.585966  1.000000
# Life_Expectancy  0.130302 -0.743655         0.742456    0.784338  0.572650
# Freedom          0.010353 -0.537942         0.551258    0.340511  0.420361
# Gov_Corruption  -0.122264 -0.372781         0.398418    0.306307  0.126401
# ...

# %%
plt.matshow(df.corr())
plt.show()
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_7252\1101004349.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr())

# %%
# Save figure
plt.matshow(df.corr())
plt.savefig("out.png")
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_7252\3452587058.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr())

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\brian\\OneDrive\\Desktop'

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_7252\464900279.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr(), fignum=f.number) # type of plot
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Rank', 'Happiness Score', 'GDP_Capita', 'Family',
#        'Life_Expectancy', 'Freedom', 'Gov_Corruption', 'Generosity',
#        'Dystopia', 'Region'],
#       dtype='object')

# %%
# Create a subset excluding the "Date" and "No" columns


# Create a subset excluding  Rank, Year, Dystopia, and Region

sub = df[['Country', 'Happiness Score', 'GDP_Capita', 'Family','Life_Expectancy', 'Freedom','Gov_Corruption', 'Generosity']]

# %%
sub
# Out:
#                       Country  Happiness Score  GDP_Capita   Family  \
# 0                 Switzerland            7.587     1.39651  1.34951
# 1                     Iceland            7.561     1.30232  1.40223
# 2                     Denmark            7.527     1.32548  1.36058
# 3                      Norway            7.522     1.45900  1.33095
# 4                      Canada            7.427     1.32629  1.32261
# ..                        ...              ...         ...      ...
# 777                    Rwanda            3.334     0.35900  0.71100
# 778                  Tanzania            3.231     0.47600  0.88500
# 779               Afghanistan            3.203     0.35000  0.51700
# 780  Central African Republic            3.083     0.02600  0.00000
# 781               South Sudan            2.853     0.30600  0.57500
#
#      Life_Expectancy  Freedom  Gov_Corruption  Generosity
# 0            0.94143  0.66557         0.41978     0.29678
# ...

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax)
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_7252\4095056021.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = sns.heatmap(sub.corr(), annot = True, ax = ax)

# %%
#4 Create a scatterplot (or plots) for the variables with the strongest correlations and examine the nature of their relationships.

# %%
sns.lmplot(x = 'Happiness Score', y = 'Freedom', data = df)

# %%
sns.lmplot(x = 'Happiness Score', y = 'GDP_Capita', data = df)

# %%
sns.lmplot(x = 'Happiness Score', y = 'Life_Expectancy', data = df)

# %%
#5 Create a pair plot 

g = sns.pairplot(sub)

# %%
#6 Create a categorical plot and interpret the results

# %%
sns.histplot(df['Happiness Score'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Count'>

# %%
df.loc[df['Happiness Score'] <10.0, 'Happiness category'] = 'Very High'

# %%
df.loc[df['Happiness Score'] < 7.0, 'Happiness category'] = 'High'

# %%
df.loc[df['Happiness Score'] < 6.0, 'Happiness category'] = 'Moderate'

# %%
df.loc[df['Happiness Score'] < 4.0, 'Happiness category'] = 'Low'

# %%
df.loc[df['Happiness Score']  < 3.0, 'Happiness category'] = 'Very Low'

# %%
df['Happiness category'].value_counts(dropna = False)
# Out:
# Moderate     451
# High         163
# Low           89
# Very High     72
# Very Low       7
# Name: Happiness category, dtype: int64

# %%
g = sns.catplot(x="GDP_Capita", y="Happiness Score", hue="Happiness category", data=df)

# %%
# fig = g.get_figure()
g.savefig("out.png")

# %%
#7 Revisit the questions you generated in the previous task and write answers to those you can based on the exploration you’ve conducted so far. Add any new questions that may have arisen based on the early findings in your visual exploration.

# %%
#Happiness scores are influenced by factors such as GDP, social support, and life expectancy, all showing a positive correlation. If a country has a low GDP per capita, it tends to have a lower happiness score. The strong correlation between life expectancy and GDP makes it challenging to pinpoint whether one is more directly linked to happiness. Logically, it is assumed that a high GDP contributes to both high life expectancy and happiness, suggesting that GDP may play a more significant role in causation than life expectancy.

# %%
#8 hypotheses that you can at this point. You’ll be testing these later on

# %%
#If a country has a high score for Freedom, then it will be happier
